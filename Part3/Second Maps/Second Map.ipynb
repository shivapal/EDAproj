# %%
library(twitteR)
library(rtweet)
library('revgeo')
library("ggmap")
library("maptools")
library(maps)
library(viridis)
library(ggthemes)
library(fiftystater)

# %%
# API_Key, API_Secret
consumer_key <- "y7Hd2hpV1mrtNoqyadIXjfH4c"
consumer_secret <- "gm3fhY3wHsJJZFykDafLBqYkNN5vL8ltQKgg746lfRU2qzq1Ky"
access_token <- "935345877715243008-qqzLBe0YhamrabXw6bkHQYymIRmRisG"
access_secret <- "reCFuv7atTTMTvnhlrqCzZ1QV4QAg2NgFd8Wi4QuLyd2k"
setup_twitter_oauth(consumer_key, consumer_secret, access_token, access_secret)
token <- create_token(
    app = "cse487/587Lab1",
    consumer_key = "y7Hd2hpV1mrtNoqyadIXjfH4c",
    consumer_secret ="gm3fhY3wHsJJZFykDafLBqYkNN5vL8ltQKgg746lfRU2qzq1Ky",
    access_token = "935345877715243008-qqzLBe0YhamrabXw6bkHQYymIRmRisG",
    access_secret = "reCFuv7atTTMTvnhlrqCzZ1QV4QAg2NgFd8Wi4QuLyd2k")

API_KEY = "AIzaSyBhwlrve8M5bM7NyRJ82G8xfyhCzxuVAzg"
register_google(key = API_KEY)
# Out:
# [1] "Using direct authentication"

# %%
states1 <- read.csv("secondMapData.csv")
states2 <- read.csv("thirdMapData.csv")

# %%
usa <- map_data("state")

# %%
# Read the data and plot
# Keyword flu
# Second map
gg <- ggplot() + 
    geom_map(data = usa, map = fifty_states, 
             aes(x=long, y = lat, map_id=region),
             color = "white",  fill = NA)
gg <- gg + geom_map(data = states1, map = fifty_states, 
                    aes(fill=freq, map_id = region), 
                    color = 'white', size = 0.5) +
        expand_limits(x = fifty_states$long, y = fifty_states$lat) + coord_map() 
gg <- gg + scale_fill_viridis(name = "# of Tweets",
                              begin = 0.1, end =0.56)
# gg <- gg + theme(legend.position = "right") 

gg <- gg + scale_x_continuous(breaks = NULL) + 
  scale_y_continuous(breaks = NULL) +
  labs(x = "", y = "") +
  theme(panel.background = element_blank())
gg
# Out:
# Warning message:
# "Ignoring unknown aesthetics: x, y"
# plot without title

# %%
# Read the data and plot
# Third map
# Key word fightflu & influenza 
gg <- ggplot() + 
    geom_map(data = usa, map = fifty_states, 
             aes(x=long, y = lat, map_id=region),
             color = "white",  fill = NA)
gg <- gg + geom_map(data = states2, map = fifty_states, 
                    aes(fill=freq, map_id = region), 
                    color = 'white', size = 0.5) +
        expand_limits(x = fifty_states$long, y = fifty_states$lat) + coord_map() 
gg <- gg + scale_fill_viridis(name = "# of Tweets",
                              begin = 0.1, end =0.56)
# gg <- gg + theme(legend.position = "right") 

gg <- gg + scale_x_continuous(breaks = NULL) + 
  scale_y_continuous(breaks = NULL) +
  labs(x = "", y = "") +
  theme(panel.background = element_blank())
gg
# Out:
# Warning message:
# "Ignoring unknown aesthetics: x, y"
# plot without title
